# %%
builtin:
	zip：
		zip(*zib_obj) --> unpack a zip
	iter:
		convert a Iterable to a Iterator
		for called iter
	map:
		return element
	filter:
		True element
	round:
		'%.2'1.235 --> '1.24'
		round(1.235, 2) --> 1.24

	all | any

	min | max | sum

	nonlocal locals() global globals()

	reflect:
		__import__('list.text.commons',fromlist=True)
		getattr		setattr		hasattr		delattr		eval
		Creates an object from a string and manipulates its members

	eval | exec | compile:
		Evaluate the given source in the context of globals and locals.

byte：
	b'中文' —-> bytes can only contain ASCII literal characters.
	decode
	encode

int:
	int() --> Arguments can only be Numbers or strings of integer

str:
	str() -->

list:
	convert a Iterable sequence to a list
	[].sort(key=None, revserse=False)   change source list ,return None.
	sorted(key=(k1,k2,))				common function ,not change source list return a new list.

dict：
	fromkeys	Keys refer to the same object, and when the reference object is a mutable type, ambiguity occurs .
	a = [2,3]	l = dict.fromkeys([1,2],a)	import sys	sys.getrefcount(a)	4
	dict(["name", "sq"],["age",22]) 	tuple too

functools：
	reduce()	The sum and the multiplication
	namedtuple()

collections:
	Counter("")
	Iterable
	Iterator
	【Generator】	yield and ()
	namedtuple()

random：
	randint
	random
	shuffle

re:
	【(.*?)】   Non - evil containing matched subexpression
	【compile】 Compiles regular expression string, after the explanation forms
				the correlation code, cannot give a string to be able to match.
	sub(re,replacement,src_str)
	findall()
	match
	search

numpy
	np.array().flatten().tolist()

mmap：
	To map a file or other object into memory
